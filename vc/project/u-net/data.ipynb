# %%
import glob
import cv2
import re
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
root_path = 'lgg-mri-segmentation/kaggle_3m/'
all_files = glob.glob(root_path + "*/*.tif")
#print('total number of files:', len(all_files))
#mask_files = [file for file in all_files if file.endswith("_mask.tif")]
#print('number of mask files:', len(mask_files))
#image_files = [file for file in all_files if not file.endswith("_mask.tif")]
#print('number of image files:', len(image_files))

# %%
root_path = 'lgg-mri-segmentation/all/'
all_files = glob.glob(root_path + "*.tif")

# %%
image_files = [file for file in os.listdir(root_path) if not file.endswith("_mask.tif")]

# %%
file = 'TCGA_CS_4941_19960909_1.tif'
number = file.split("_")[-1]
number = after.split(".tif")[0]
number = int(number)
number
# Out:
# 1

# %%
int(file.split("_")[-1].split(".tif")[0])
# Out:
# 1

# %%
tuple_list = []
for file in image_files:
    tuple_list.append((file, int(file.split("_")[-1].split(".tif")[0])))
sorted(tuple_list, key=lambda x: x[1])
# Out:
# [('TCGA_DU_8164_19970111_1.tif', 1),
#  ('TCGA_HT_8114_19981030_1.tif', 1),
#  ('TCGA_DU_8165_19970205_1.tif', 1),
#  ('TCGA_DU_7309_19960831_1.tif', 1),
#  ('TCGA_CS_5393_19990606_1.tif', 1),
#  ('TCGA_DU_5853_19950823_1.tif', 1),
#  ('TCGA_DU_7301_19911112_1.tif', 1),
#  ('TCGA_HT_7692_19960724_1.tif', 1),
#  ('TCGA_DU_5855_19951217_1.tif', 1),
#  ('TCGA_FG_7643_20021104_1.tif', 1),
#  ('TCGA_FG_6689_20020326_1.tif', 1),
#  ('TCGA_DU_A5TP_19970614_1.tif', 1),
#  ('TCGA_CS_6667_20011105_1.tif', 1),
#  ('TCGA_DU_5872_19950223_1.tif', 1),
#  ('TCGA_FG_6690_20020226_1.tif', 1),
#  ('TCGA_HT_8113_19930809_1.tif', 1),
#  ('TCGA_HT_7884_19980913_1.tif', 1),
#  ('TCGA_HT_7605_19950916_1.tif', 1),
#  ('TCGA_DU_8166_19970322_1.tif', 1),
#  ('TCGA_FG_6692_20020606_1.tif', 1),
#  ('TCGA_FG_7637_20000922_1.tif', 1),
#  ('TCGA_DU_5852_19950709_1.tif', 1),
#  ('TCGA_HT_8105_19980826_1.tif', 1),
#  ('TCGA_DU_7294_19890104_1.tif', 1),
#  ('TCGA_DU_7306_19930512_1.tif', 1),
# ...
